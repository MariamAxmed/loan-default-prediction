# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
from src.preprocessing import (
    load_data,
    remove_index_column,
    fill_missing_values,
)

df = load_data()
df = remove_index_column(df)
df = fill_missing_values(df)

df.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                 1                              0.766127   45
# 1                 0                              0.957151   40
# 2                 0                              0.658180   38
# 3                 0                              0.233810   30
# 4                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                               13                        0
# 1                                4                        0
# ...

# %%
from src.feature_engineering import cap_outliers

# %%
df = cap_outliers(df)

df.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines           age  \
# count     150000.000000                         150000.000000  150000.00000
# mean           0.066840                              0.322261      52.29422
# std            0.249746                              0.356572      14.76839
# min            0.000000                              0.000000       8.00000
# 25%            0.000000                              0.029867      41.00000
# 50%            0.000000                              0.154181      52.00000
# 75%            0.000000                              0.559046      63.00000
# max            1.000000                              1.352814      96.00000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                              150000.0  150000.000000  150000.000000
# mean                                    0.0       0.663258    5877.247510
# ...

# %%
from src.visualization import plot_boxplots

# %%
plot_boxplots(df)

# %%
from src.preprocessing import split_features_target
from src.feature_engineering import scale_features

X, y = split_features_target(df)

X_scaled, scaler = scale_features(X)

X_scaled.head()
# Out:
#    RevolvingUtilizationOfUnsecuredLines       age  \
# 0                              1.244820 -0.493909
# 1                              1.780547 -0.832471
# 2                              0.942085 -0.967896
# 3                             -0.248060 -1.509595
# 4                              1.640570 -0.223060
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                   0.0   0.203063       1.064977
# 1                                   0.0  -0.786797      -1.076306
# 2                                   0.0  -0.840225      -0.931145
# 3                                   0.0  -0.911530      -0.846414
# 4                                   0.0  -0.927696       2.222813
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                         0.986383                      0.0
# 1                        -0.913688                      0.0
# 2                        -1.335926                      0.0
# ...
